# %% [markdown]
# # Correlazioni inverse tra ETF
# ## Obbiettivi
# 1. Analizzare mercati di diverso tipo identificando coppie di mercati con correlazioni negative consistenti.
#
# 2. Tra le coppie individuate ricercare ed analizzare periodi in cui la correlazione è momentaneamente cambiata.
#
# 3. Valutare la possibilità di applicazione di una strategia long/short temite il calcolo dello z-score.

# %% [markdown]
# ### Importazione librerie necessarie

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download datasets dei mercati

# %%
# Step 1: Download historical data
tickers = [
'SPY','TLT',
'GLD','UUP',
'QQQ','VXX',
'SH','IWM',
'SLV','TIP'
]

df = yf.download(tickers, start='2015-01-01', end='2024-12-31', period='1d')
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df.head()
# Out:
# Price            Close                                                        \
# Ticker             GLD         IWM        QQQ          SH    SLV         SPY
# Date
# 2015-01-02  114.080002  103.894646  95.123299  166.532669  15.11  172.075226
# 2015-01-05  115.800003  102.505669  93.727959  169.281479  15.50  168.967651
# 2015-01-06  117.120003  100.732315  92.471245  171.114029  15.83  167.376083
# 2015-01-07  116.430000  101.972786  93.663269  168.823364  15.85  169.461868
# 2015-01-08  115.940002  103.702477  95.455948  165.921814  15.64  172.468964
#
# Price                                             ...    Volume            \
# Ticker            TIP         TLT        UUP VXX  ...       GLD       IWM
# Date                                              ...
# 2015-01-02  86.913811   97.964394  20.907146 NaN  ...   7109600  46133100
# 2015-01-05  86.983223   99.503258  20.950342 NaN  ...   8177400  51141900
# ...
